# %% [markdown]
# ### 수를 이용한 프로그램 구현
#  - up & down
#  - 구구단 프로그램
#  - 계산기프로그램
#  - 계산기 응용

# %% [markdown]
# #### up & down 프로그램 구현
#  - 반복문을 이용해서 시스템이 설정한 랜덤 숫자를 맞추기
#  - 난수 생성은 random 이용하기

# %%
# 난수 생성하기
import random

r = random.randint(1,100) # 난수

# 반복문 만들기
while True:
    num = int(input("1부터 100사이의 수를 입력해주세요 : "))
    if r == num:
        print("생성된 숫자는 {}가 맞습니다.".format(num))
        break
    if r > num:
        print("해당 숫자보다 큰 수 입니다.")
    else:
        print("해당 숫자보다 작은 수 입니다.")
# Out:
# 1부터 100사이의 수를 입력해주세요 : 50
# 해당 숫자보다 큰 수 입니다.
# 1부터 100사이의 수를 입력해주세요 : 75
# 해당 숫자보다 작은 수 입니다.
# 1부터 100사이의 수를 입력해주세요 : 60
# 해당 숫자보다 큰 수 입니다.
# 1부터 100사이의 수를 입력해주세요 : 63
# 해당 숫자보다 큰 수 입니다.
# 1부터 100사이의 수를 입력해주세요 : 70
# 해당 숫자보다 큰 수 입니다.
# 1부터 100사이의 수를 입력해주세요 : 73
# 해당 숫자보다 큰 수 입니다.
# 1부터 100사이의 수를 입력해주세요 : 74
# 생성된 숫자는 74가 맞습니다.

# %%
# 제한된 횟수 안에 숫자 맞추기

import random
rnum = random.randint(1,50) # 1 부터 50 안의 숫자를 랜덤으로 생성
while 1:
    
    for i in range(5):
        num = int(input("choose number: "))
        if num == rnum:
            print("thah's right the number is %d !" % num)
            break
        elif num > rnum:
            print(" more small number")
        else:
            print(" more big number")
    else:
        print("\n oh... random number is %d" %rnum)
        break

# %% [markdown]
# #### 구구단 프로그램
#  - 입력받은 단수만 출력
#  - 전체 단수 출력

# %%
# 단수를 입력하면 해당 수의 구구단을 출력하는 프로그램 (처음시도)
for i in range(9):
    n = int(input("출력하고자 하는 단수를 입력하세요: "))
    print("\n==== %d단 ====" % n)
    print(" {0} X {1} = {2}".format(n, i, n*1))
# Out:
# 출력하고자 하는 단수를 입력하세요: 9
# ==== 9단 ====
#
#  9 X 0 = 9

# %%
# 안돼서 한 번 보고
while True:
    n = int(input("단수를 입력하세요(프로그램 종료를 원할시 0을 입력하세요): "))
    if n == 0:
        print("\t 프로그램이 종료됩니다.")
        break
    print("\n=== %d단 ===" %n)
    for i in range(1,10):  
        print("{0} X {1} = {2}".format(n, i, n * i))
# Out:
# 단수를 입력하세요(프로그램 종료를 원할시 0을 입력하세요): 2
#
# === 2단 ===
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# 단수를 입력하세요(프로그램 종료를 원할시 0을 입력하세요): 0
# 	 프로그램이 종료됩니다.

# %%
# 전체 단수 출력
for i in range(1,10):
    print("\n=== %d단 ===" %i)
    for j in range(1,10):
        print("{}X{}={}".format(i, j, i*j))
# Out:
# === 1단 ===
# 1X1=1
# 1X2=2
# 1X3=3
# 1X4=4
# 1X5=5
# 1X6=6
# 1X7=7
# 1X8=8
# 1X9=9
#
# === 2단 ===
# 2X1=2
# 2X2=4
# 2X3=6
# 2X4=8
# 2X5=10
# 2X6=12
# 2X7=14
# 2X8=16
# 2X9=18
#
# === 3단 ===
# 3X1=3
# 3X2=6
# 3X3=9
# 3X4=12
# 3X5=15
# 3X6=18
# 3X7=21
# 3X8=24
# 3X9=27
#
# === 4단 ===
# 4X1=4
# 4X2=8
# 4X3=12
# 4X4=16
# 4X5=20
# 4X6=24
# 4X7=28
# 4X8=32
# 4X9=36
#
# === 5단 ===
# 5X1=5
# 5X2=10
# 5X3=15
# 5X4=20
# 5X5=25
# 5X6=30
# 5X7=35
# 5X8=40
# 5X9=45
#
# === 6단 ===
# 6X1=6
# 6X2=12
# 6X3=18
# 6X4=24
# 6X5=30
# 6X6=36
# 6X7=42
# 6X8=48
# 6X9=54
#
# === 7단 ===
# 7X1=7
# 7X2=14
# 7X3=21
# 7X4=28
# 7X5=35
# 7X6=42
# 7X7=49
# 7X8=56
# 7X9=63
#
# === 8단 ===
# 8X1=8
# 8X2=16
# 8X3=24
# 8X4=32
# 8X5=40
# 8X6=48
# 8X7=56
# 8X8=64
# 8X9=72
#
# === 9단 ===
# 9X1=9
# 9X2=18
# 9X3=27
# 9X4=36
# 9X5=45
# 9X6=54
# 9X7=63
# 9X8=72
# 9X9=81

# %% [markdown]
# #### 계산기 프로그램
# - 사칙연산을 구현하는 프로그램을 작성하시오.

# %%
# # 숫자 두개를 입력받는 함수
# def getn1():
#     n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
#     return n1
#  #n2 = int(input("연산하고자 하는 두번째 수를 입력하시오 : "))
    
# 더하기 프로그램
def dhg():
    print("\t{} + {} = {}".format(n1, n2, n1 + n2))
    print("더하기가 완료되었습니다.")

# 빼기 프로그램
def ppg():
    print("\t{} - {} = {}".format(n1, n2, n1 - n2))
    print("빼기가 완료되었습니다.")
    
# 곱하기 프로그램
def ghg():
    print("\t{} X {} = {}".format(n1, n2, n1 * n2))
    print("곱하기가 완료되었습니다.")
    
def nng():
    print("\t{} / {} = {}".format(n1, n2, n1 / n2))
    print("나누기가 완료되었습니다.")
    
#메뉴프로그램
def showMenu():
    print("\n=== 사칙연산 프로그램 ===")
    print("1. 더하기 연산")
    print("2. 빼기 연산")
    print("3. 곱하기 연산")
    print("4. 나누기 연산")
    print("5. 프로그램 종료")
    print("="*20)

# %%
# # 연습 1    
# def calProgram():
#     while 1:
#         showMenu()
#         menu = input("메뉴를 선택하시오 :")
#         if menu == "5":
#             print("\t프로그램이 종료됩니다.")
#             break
#        # elif menu != "1" or menu != "2" or menu != "3" or menu != "4":
#         else:
#             print("잘못된 메뉴입니다. 다시 선택해주세요.")
#             return calProgram()
            
# #         global n1 # 함수안에 사용가능하도록 전역변수 설정해준거
# #         global n2
# #         n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
# #         n2 = int(input("연산하고자 하는 두번째 수를 입력하시오 : "))
#         elif menu == "1":
        
#         elif menu == "2":
#             ppg()
#         elif menu == "3":
#             ghg()
#         elif menu == "4":
#             nng()
        
# calProgram()
# Out:
#   Input In [11]
#     elif menu == "1":
#     ^
# SyntaxError: invalid syntax

# %%
# # 연습 2
# global n1
# global n2
# def calProgram():
#     while 1:
#         showMenu()
#         menu = input("메뉴를 선택하시오 :")
#         if menu == "1":
#             n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
#             n2 = int(input("연산하고자 하는 두번째 수를 입력하시오 : "))
#             dhg()
#         elif menu == "2":
#             n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
#             n2 = int(input("연산하고자 하는 두번째 수를 입력하시오 : "))
#             ppg()
#         elif menu == "3":
#             n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
#             n2 = int(input("연산하고자 하는 두번째 수를 입력하시오 : "))
#             ghg()
#         elif menu == "4":
#             n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
#             n2 = int(input("연산하고자 하는 두번째 수를 입력하시오 : "))
#             nng()
#         elif menu == "5":
#             print("\t프로그램이 종료됩니다.")
#             break
#         else:
#             print("잘못된 메뉴입니다. 다시 선택해주세요.")
#             return calProgram()
        
# calProgram()
# Out:
# === 사칙연산 프로그램 ===
# 1. 더하기 연산
# 2. 빼기 연산
# 3. 곱하기 연산
# 4. 나누기 연산
# 5. 프로그램 종료
# ====================
# 메뉴를 선택하시오 :1
# 연산하고자 하는 첫번째 수를 입력하시오 : 12
# 연산하고자 하는 두번째 수를 입력하시오 : 24
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [24], in <cell line: 31>()
#      28             print("잘못된 메뉴입니다. 다시 선택해주세요.")
#      29             return calProgram()
# ---> 31 calProgram()
#
# Input In [24], in calProgram()
#       9     n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
#      10     n2 = int(input("연산하고자 하는 두번째 수를 입력하시오 : "))
# ---> 11     dhg()
#      12 elif menu == "2":
#      13     n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
#
# Input In [19], in dhg()
#       8 def dhg():
# ----> 9     print("\t{} + {} = {}".format(n1, n2, n1 + n2))
#      10     print("더하기가 완료되었습니다.")
#
# NameError: name 'n1' is not defined

# %%
# 최종 프로그램 제작
def calProgram():
    while 1:
        showMenu()
        menu = input("메뉴를 선택하시오 :")
        M = "1","2","3","4"
        
        if menu in M:
            global n1
            global n2
            n1 = int(input("연산하고자 하는 첫번째 수를 입력하시오 : "))
            n2 = int(input("연산하고자 하는 두번째 수를 입력하시오 : "))
            
            if menu == "1":
                dhg()
            elif menu == "2":
                ppg()
            elif menu == "3":
                ghg()
            elif menu == "4":
                nng()
        if menu not in M:
            if menu == "5":
                print("\t프로그램이 종료됩니다.")
                break
            else:
                print("잘못된 메뉴입니다. 다시 선택해주세요.")
                return calProgram()

calProgram()
# Out:
# === 사칙연산 프로그램 ===
# 1. 더하기 연산
# 2. 빼기 연산
# 3. 곱하기 연산
# 4. 나누기 연산
# 5. 프로그램 종료
# ====================
# 메뉴를 선택하시오 :1
# 연산하고자 하는 첫번째 수를 입력하시오 : 12
# 연산하고자 하는 두번째 수를 입력하시오 : 24
# 	12 + 24 = 36
# 더하기가 완료되었습니다.
#
# === 사칙연산 프로그램 ===
# 1. 더하기 연산
# 2. 빼기 연산
# 3. 곱하기 연산
# 4. 나누기 연산
# 5. 프로그램 종료
# ====================
# 메뉴를 선택하시오 :2
# 연산하고자 하는 첫번째 수를 입력하시오 : 24
# 연산하고자 하는 두번째 수를 입력하시오 : 14
# 	24 - 14 = 10
# 빼기가 완료되었습니다.
#
# === 사칙연산 프로그램 ===
# 1. 더하기 연산
# 2. 빼기 연산
# 3. 곱하기 연산
# 4. 나누기 연산
# 5. 프로그램 종료
# ====================
# 메뉴를 선택하시오 :3
# 연산하고자 하는 첫번째 수를 입력하시오 : 21
# 연산하고자 하는 두번째 수를 입력하시오 : 4
# 	21 X 4 = 84
# 곱하기가 완료되었습니다.
#
# === 사칙연산 프로그램 ===
# 1. 더하기 연산
# 2. 빼기 연산
# 3. 곱하기 연산
# 4. 나누기 연산
# 5. 프로그램 종료
# ====================
# 메뉴를 선택하시오 :4
# 연산하고자 하는 첫번째 수를 입력하시오 : 62
# 연산하고자 하는 두번째 수를 입력하시오 : 31
# 	62 / 31 = 2.0
# 나누기가 완료되었습니다.
#
# === 사칙연산 프로그램 ===
# 1. 더하기 연산
# 2. 빼기 연산
# 3. 곱하기 연산
# 4. 나누기 연산
# 5. 프로그램 종료
# ====================
# 메뉴를 선택하시오 :5
# 	프로그램이 종료됩니다.

# %% [markdown]
# #### 계산기 응용버전(멀티 프로그램)
#  - 최댓값, 사칙연산, 수와 열 작업을 구현하는 프로그램을 생성하시오.

# %%
# 최댓값구하기
def maxN():
    n1 = int(input(" write first number :"))
    n2 = int(input(" write second number :"))
    if n1 > n2:
        print(" the bigger one is %d " % n1)
    elif n1 == n2:
        print(" they are same number")
    else:
        print(" the bigger one is %d " % n2)
        
# 사칙연산
def cal():
    s1 = int(input(" write first number :"))
    mark = input("chooser one(+, -, *, /) : ")
    s2 = int(input(" write second number :"))
    if mark == "+":
        print("{0} + {1} = {2}".format(s1, s2, s1 + s2))
    elif mark == "-":
        print("{0} - {1} = {2}".format(s1, s2, s1 - s2))
    elif mark == "*":
        print("{0} × {1} = {2}".format(s1, s2, s1 * s2))
    elif mark == "/":
        print("{0} ÷ {1} = {2}".format(s1, s2, s1 / s2))
    else:
        print("\n that's wrong choice, try again")
        return cal()
    
# 수나열
suList = list()
def su():
    x1 = int(input(" write first number :"))
    x2 = int(input(" write second number :"))
    x3 = int(input(" write third number :"))
    
    suList.append(x1)
    suList.append(x2)
    suList.append(x3)
    suList.sort(reverse = True)  # 바보 sort는 오름차순이라 큰순으로 하려면 리버스...
    print(suList)

# 메뉴 프로그램
def sMenu():
    print("=== Multi Program ===")
    print("1. What's big number?")
    print("2. Calculator program")
    print("3. Sort numbers")
    print("4. End the program")
    print("="*20)
    
def mProgram():
    sMenu()
    while 1:
     #   global mn
        mn = input("\t choice the menu : ")
        if mn == "1":
            print("\n <what's big number?>")
            maxN()
        elif mn == "2":
            print("\n <calculator program>")
            cal()
        elif mn == "3":
            print("\n <sort numbers>")
            su()
        elif mn == "4":
            print("\t *Program Over*")
            break
        else:
            print("\n that's wong menu, please one more check")
            return mProgram()

# %%
mProgram()
# Out:
# === Multi Program ===
# 1. What's big number?
# 2. Calculator program
# 3. Sort numbers
# 4. End the program
# ====================
# 	 choice the menu : 1
#
#  <what's big number?>
#  write first number :23
#  write second number :32
#  the bigger one is 32
# 	 choice the menu : 2
#
#  <calculator program>
#  write first number :1
# chooser one(+, -, *, /) : +
#  write second number :9
# 1 + 9 = 10
# 	 choice the menu : 3
#
#  <sort numbers>
#  write first number :24
#  write second number :51
#  write third number :10
# [51, 24, 10]
# 	 choice the menu : 6
#
#  that's wong menu, please one more check
# === Multi Program ===
# 1. What's big number?
# 2. Calculator program
# 3. Sort numbers
# 4. End the program
# ====================
# 	 choice the menu : 4
# 	 *Program Over*
